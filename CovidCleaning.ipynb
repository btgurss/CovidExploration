# %%
import pandas as pd
import numpy as np

# %%
filename = '../Data/CovidData.csv'

# %%
data=[]
count=0

# %%
data = pd.read_csv(filename, nrows=20000)

# %%
data.head()
# Out:
#   case_month res_state  state_fips_code           res_county  \
# 0    2021-08        AL                1                 PIKE
# 1    2021-08        TN               47               COFFEE
# 2    2020-12        MO               29             CRAWFORD
# 3    2021-12        VA               51        HOPEWELL CITY
# 4    2020-07        VA               51  VIRGINIA BEACH CITY
#
#    county_fips_code       age_group     sex   race            ethnicity  \
# 0            1109.0         Missing  Female  White  Non-Hispanic/Latino
# 1           47031.0  18 to 49 years  Female  White  Non-Hispanic/Latino
# 2           29055.0  18 to 49 years  Female  White  Non-Hispanic/Latino
# 3           51670.0  18 to 49 years  Female  White  Non-Hispanic/Latino
# 4           51810.0  18 to 49 years  Female  White  Non-Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval  process exposure_yn  \
# 0                              NaN                  NaN  Missing     Missing
# ...

# %%
data['icu_yn'] = data['icu_yn'].replace(['Missing', 'Unknown'], 'No')
data.head()
# Out:
#   case_month res_state           res_county       age_group     sex   race  \
# 0    2021-08        AL                 PIKE         Missing  Female  White
# 1    2021-08        TN               COFFEE  18 to 49 years  Female  White
# 2    2020-12        MO             CRAWFORD  18 to 49 years  Female  White
# 3    2021-12        VA        HOPEWELL CITY  18 to 49 years  Female  White
# 4    2020-07        VA  VIRGINIA BEACH CITY  18 to 49 years  Female  White
#
#              ethnicity symptom_status  hosp_yn icu_yn death_yn  \
# 0  Non-Hispanic/Latino        Missing       No     No  Missing
# 1  Non-Hispanic/Latino        Missing  Missing     No  Missing
# 2  Non-Hispanic/Latino    Symptomatic  Unknown     No  Unknown
# 3  Non-Hispanic/Latino    Symptomatic       No     No      NaN
# 4  Non-Hispanic/Latino    Symptomatic       No     No       No
#
#   underlying_conditions_yn
# 0                      NaN
# 1                      NaN
# 2                      Yes
# ...

# %%
data['icu_yn'].value_counts()
# Out:
# No     19930
# Yes       70
# Name: icu_yn, dtype: int64

# %%
data = data.drop(['state_fips_code', 'county_fips_code', 'case_positive_specimen_interval', 'case_onset_interval', 'process', 'exposure_yn', 'current_status'], axis=1)
data.head()
# Out:
#   case_month res_state           res_county       age_group     sex   race  \
# 0    2021-08        AL                 PIKE         Missing  Female  White
# 1    2021-08        TN               COFFEE  18 to 49 years  Female  White
# 2    2020-12        MO             CRAWFORD  18 to 49 years  Female  White
# 3    2021-12        VA        HOPEWELL CITY  18 to 49 years  Female  White
# 4    2020-07        VA  VIRGINIA BEACH CITY  18 to 49 years  Female  White
#
#              ethnicity symptom_status  hosp_yn   icu_yn death_yn  \
# 0  Non-Hispanic/Latino        Missing       No  Missing  Missing
# 1  Non-Hispanic/Latino        Missing  Missing  Missing  Missing
# 2  Non-Hispanic/Latino    Symptomatic  Unknown  Missing  Unknown
# 3  Non-Hispanic/Latino    Symptomatic       No  Missing      NaN
# 4  Non-Hispanic/Latino    Symptomatic       No  Missing       No
#
#   underlying_conditions_yn
# 0                      NaN
# 1                      NaN
# 2                      Yes
# ...
